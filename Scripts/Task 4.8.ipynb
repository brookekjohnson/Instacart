# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
# Import ords_prods_merge data
df = pd.read_pickle(r'C:\Users\Brooke\05-2022 Instacart Basket Analysis\Data\Prepared Data\ords_prods_merge.pkl')

# %%
df.head()
# Out:
#    user_id  order_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0        1   2539329             1                   2                  8
# 1        1   2539329             1                   2                  8
# 2        1   2539329             1                   2                  8
# 3        1   2539329             1                   2                  8
# 4        1   2539329             1                   2                  8
#
#    days_since_prior_order  has_prior_orders  product_id  add_to_cart_order  \
# 0                     NaN             False         196                  1
# 1                     NaN             False       14084                  2
# 2                     NaN             False       12427                  3
# 3                     NaN             False       26088                  4
# 4                     NaN             False       26405                  5
#
# ...

# %%
df.shape
# Out:
# (32435059, 21)

# %% [markdown]
# # 03. Creating Groups

# %%
# calculate aggregated mean of order_number grouped by department_id
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     15.457838
# 2.0     17.277920
# 3.0     17.170395
# 4.0     17.811403
# 5.0     15.215751
# 6.0     16.439806
# 7.0     17.225802
# 8.0     15.340650
# 9.0     15.895474
# 10.0    20.197148
# 11.0    16.170638
# 12.0    15.887671
# 13.0    16.583536
# 14.0    16.773669
# 15.0    16.165037
# 16.0    17.665606
# 17.0    15.694469
# 18.0    19.310397
# 19.0    17.177343
# 20.0    16.473447
# 21.0    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# # the means of the entire dataframe are close to, but not the exact same as those in the subset, which makes sense because there are a lot more numbers being calculated into the mean of the entire dataframe.

# %% [markdown]
# # loyalty flag was created in previous exercise and can be seen in the dataframe head function above

# %%
#compare basic statistics of different types of customers
df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
#calculating average prices for each user
df.groupby('user_id').agg({'prices': ['mean']})
# Out:
#            prices
#              mean
# user_id
# 1        6.367797
# 2        7.515897
# 3        8.197727
# 4        8.205556
# 5        9.189189
# ...           ...
# 206205   8.909375
# 206206   7.646667
# 206207   7.313453
# 206208   8.366617
# 206209   7.058915
#
# [206209 rows x 1 columns]

# %%
#create new column for average prices
df['average_prices'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df.head()
# Out:
#    user_id  order_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0        1   2539329             1                   2                  8
# 1        1   2539329             1                   2                  8
# 2        1   2539329             1                   2                  8
# 3        1   2539329             1                   2                  8
# 4        1   2539329             1                   2                  8
#
#    days_since_prior_order  has_prior_orders  product_id  add_to_cart_order  \
# 0                     NaN             False         196                  1
# 1                     NaN             False       14084                  2
# 2                     NaN             False       12427                  3
# 3                     NaN             False       26088                  4
# 4                     NaN             False       26405                  5
#
# ...

# %%
df.shape
# Out:
# (32435059, 22)

# %%
# create spending_flag
df.loc[df['average_prices'] < 10, 'spending_flag'] = 'Low spender'

# %%
df.loc[df['average_prices'] >= 10, 'spending_flag'] = 'High spender'

# %%
df.head(100)
# Out:
#     user_id  order_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         1   2539329             1                   2                  8
# 1         1   2539329             1                   2                  8
# 2         1   2539329             1                   2                  8
# 3         1   2539329             1                   2                  8
# 4         1   2539329             1                   2                  8
# ..      ...       ...           ...                 ...                ...
# 95        2    738281             4                   2                 10
# 96        2   1673511             5                   3                 11
# 97        2   1673511             5                   3                 11
# 98        2   1673511             5                   3                 11
# 99        2   1673511             5                   3                 11
#
# ...

# %%
#creating new column for median of days_since_prior_order
df['median_days_since_prior_order'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df.head()
# Out:
#    user_id  order_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0        1   2539329             1                   2                  8
# 1        1   2539329             1                   2                  8
# 2        1   2539329             1                   2                  8
# 3        1   2539329             1                   2                  8
# 4        1   2539329             1                   2                  8
#
#    days_since_prior_order  has_prior_orders  product_id  add_to_cart_order  \
# 0                     NaN             False         196                  1
# 1                     NaN             False       14084                  2
# 2                     NaN             False       12427                  3
# 3                     NaN             False       26088                  4
# 4                     NaN             False       26405                  5
#
# ...

# %%
#creating frequency flag
df.loc[df['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df.loc[(df['median_days_since_prior_order'] > 10) & (df['median_days_since_prior_order'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
df.loc[df['median_days_since_prior_order'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
#check data
df.head(100)
# Out:
#     user_id  order_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         1   2539329             1                   2                  8
# 1         1   2539329             1                   2                  8
# 2         1   2539329             1                   2                  8
# 3         1   2539329             1                   2                  8
# 4         1   2539329             1                   2                  8
# ..      ...       ...           ...                 ...                ...
# 95        2    738281             4                   2                 10
# 96        2   1673511             5                   3                 11
# 97        2   1673511             5                   3                 11
# 98        2   1673511             5                   3                 11
# 99        2   1673511             5                   3                 11
#
# ...

# %%
#check shape
df.shape
# Out:
# (32435059, 25)

# %% [markdown]
# # 04. Exporting Data

# %%
# Import ords_prods_merge data
df.to_pickle(r'C:\Users\Brooke\05-2022 Instacart Basket Analysis\Data\Prepared Data\grouped data.pkl')
